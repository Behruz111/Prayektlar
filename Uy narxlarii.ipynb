# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv')
df1=df.drop(['location','district'],axis=1)
df0=df[['location','district']].copy()
df1=df1.replace('Договорная',np.nan)
df1=df1.drop(5347)
df0=df0.drop(5347)
df1=df1.astype(dtype='float')
d=df1['price'].sum()/len(df1)
df1=df1.fillna(d)

# %%
dff
# Out:
#       rooms  size  level  max_levels    price  \
# 0       3.0  57.0    4.0         4.0  52000.0
# 1       2.0  52.0    4.0         5.0  56000.0
# 2       2.0  42.0    4.0         4.0  37000.0
# 3       3.0  65.0    1.0         4.0  49500.0
# 4       3.0  70.0    3.0         5.0  55000.0
# ...     ...   ...    ...         ...      ...
# 7560    1.0  38.0    5.0         5.0  24500.0
# 7561    2.0  49.0    1.0         4.0  32000.0
# 7562    2.0  64.0    3.0         9.0  40000.0
# 7563    1.0  18.0    1.0         4.0  11000.0
# 7564    1.0  30.0    2.0         4.0  22914.0
#
#                                                location           district
# 0     город Ташкент, Юнусабадский район, Юнусабад 8-...       Юнусабадский
# 1     город Ташкент, Яккасарайский район, 1-й тупик ...      Яккасарайский
# 2     город Ташкент, Чиланзарский район, Чиланзар 2-...       Чиланзарский
# 3     город Ташкент, Чиланзарский район, Чиланзар 9-...       Чиланзарский
# ...

# %%
from sklearn.model_selection import train_test_split
train_set,test_set =train_test_split(dff,test_size=0.2,random_state=42)

# %%
x=train_set.drop(['location','district'],axis=1)
y=train_set['price'].copy()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %%
numeric_pypline=Pipeline([
    ('numeric',StandardScaler())
])

# %%
a0=x.drop(['price'],axis=1)

# %%
a1=list(a0)
a2=['district']

# %%
a1
# Out:
# ['rooms', 'size', 'level', 'max_levels']

# %%
from sklearn.compose import ColumnTransformer
full_piplin = ColumnTransformer([
    ('full_num',numeric_pypline,a1),
    ('strg',OrdinalEncoder(),a2)
])

# %%
tr=train_set.drop(['price','location'],axis=1)

# %%
x_pred=full_piplin.fit_transform(tr)

# %%
from sklearn.linear_model import LinearRegression
LR_model=LinearRegression()

# %%
LR_model.fit(x_pred,y)
# Out:
# LinearRegression()

# %%
test_set1=test_set.drop(['price','location'],axis=1)

# %%
test_prep=full_piplin.fit_transform(test_set1)

# %%
xp=LR_model.predict(test_prep)

# %%
y11=test_set['price'].copy()

# %%
xp
# Out:
# array([47841.97092775, 72927.54368195, 93710.03816956, ...,
#        68711.25785636, 45419.69825245, 50034.38832527])

# %%
len(xp)
# Out:
# 1513

# %%
np.asanyarray(y11)
# Out:
# array([ 69900.,  68000., 110000., ..., 120000.,  36000.,  31000.])

# %%
len(y11)
# Out:
# 1513

# %%
from sklearn.metrics import mean_squared_error
rmse=mean_squared_error(y11,xp)
rt=np.sqrt(rmse)
rt
# Out:
# 1342361.5824504558

# %%
from sklearn.tree import DecisionTreeRegressor
tre_model=DecisionTreeRegressor()

# %%
tre_model.fit(x_pred,y)
# Out:
# DecisionTreeRegressor()

# %%
ee=tre_model.predict(test_prep)

# %%
from sklearn.metrics import mean_squared_error
r=mean_squared_error(y11,ee)
rr=np.sqrt(r)
rr
# Out:
# 1347256.622401264

# %%
from sklearn.ensemble import RandomForestRegressor
rm=RandomForestRegressor()

# %%
rm.fit(x_pred,y)
# Out:
# RandomForestRegressor()

# %%
y_te=rm.predict(test_prep)

# %%
from sklearn.metrics import mean_squared_error
r3=mean_squared_error(y11,y_te)
r1=np.sqrt(r3)
r1
# Out:
# 1344348.6571022654
